# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
#import datetime
from datetime import datetime
from scipy.stats import linregress



# Import API key
from api_keys import weather_api_key
#api_keys = "08d7af0feaa19895d5dee15b18acc9f1"
#print(api_keys)

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 630

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Starting URL for Weather Map API Call
url = 'http://api.openweathermap.org/data/2.5/weather?'
units = 'imperial'

query_url = f'{url}appid={weather_api_key}&units={units}&q='
print(query_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?appid=08d7af0feaa19895d5dee15b18acc9f1&units=imperial&q=

# %%
# Create empty lists to append the API data into lists 
city_name = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []

record = 1

# Log file print statement
print(f"Beginning Data Retrieval")
print(f"-------------------------------")

#print(cities)
#Loop through the cities in the city list 
for city in cities:
        response=requests.get(query_url + city).json()
        
        print('Processing Record ' + str(record) + ' of ' + str(len(cities)) + ' | ' + city)
        
        try:                                                
            city_name.append(response['name'])
            cloudiness.append(response['clouds']['all'])
            country.append(response['sys']['country'])
            date.append(response['dt'])
            humidity.append(response['main']['humidity'])             
            lat.append(response['coord']['lat'])
            lng.append(response['coord']['lon'])             
            max_temp.append(response['main']['temp_max'])
            wind_speed.append(response['wind']['speed'])     
        except KeyError:
            
            print(city + ' city not found. Skipping...') 
        record = record + 1
# Out:
# Beginning Data Retrieval
# -------------------------------
# Processing Record 1 of 630 | anadyr
# Processing Record 2 of 630 | partizansk
# Processing Record 3 of 630 | klaksvik
# Processing Record 4 of 630 | ushuaia
# Processing Record 5 of 630 | nikolskoye
# Processing Record 6 of 630 | gizo
# Processing Record 7 of 630 | longyearbyen
# Processing Record 8 of 630 | albany
# Processing Record 9 of 630 | east london
# Processing Record 10 of 630 | grand gaube
# Processing Record 11 of 630 | carnarvon
# Processing Record 12 of 630 | tasiilaq
# Processing Record 13 of 630 | busselton
# Processing Record 14 of 630 | vaini
# Processing Record 15 of 630 | padang
# Processing Record 16 of 630 | sulangan
# Processing Record 17 of 630 | chokurdakh
# Processing Record 18 of 630 | taolanaro
# taolanaro city not found. Skipping...
# Processing Record 19 of 630 | markivka
# Processing Record 20 of 630 | esperance
# Processing Record 21 of 630 | mayor pablo lagerenza
# Processing Record 22 of 630 | skalistyy
# skalistyy city not found. Skipping...
# Processing Record 23 of 630 | orzu
# Processing Record 24 of 630 | nelson bay
# Processing Record 25 of 630 | tuktoyaktuk
# Processing Record 26 of 630 | mataura
# Processing Record 27 of 630 | rawannawi
# rawannawi city not found. Skipping...
# Processing Record 28 of 630 | guanay
# Processing Record 29 of 630 | meulaboh
# Processing Record 30 of 630 | jamestown
# Processing Record 31 of 630 | hilo
# Processing Record 32 of 630 | san patricio
# Processing Record 33 of 630 | nishihara
# Processing Record 34 of 630 | thompson
# Processing Record 35 of 630 | arroyo
# Processing Record 36 of 630 | malwan
# malwan city not found. Skipping...
# Processing Record 37 of 630 | upernavik
# Processing Record 38 of 630 | rikitea
# Processing Record 39 of 630 | torbay
# Processing Record 40 of 630 | xuddur
# Processing Record 41 of 630 | dikson
# Processing Record 42 of 630 | marawi
# Processing Record 43 of 630 | almeirim
# Processing Record 44 of 630 | ketchikan
# Processing Record 45 of 630 | punta arenas
# Processing Record 46 of 630 | geraldton
# Processing Record 47 of 630 | santa fe
# Processing Record 48 of 630 | georgetown
# Processing Record 49 of 630 | butaritari
# Processing Record 50 of 630 | sao felix do xingu
# Processing Record 51 of 630 | hobart
# Processing Record 52 of 630 | belushya guba
# belushya guba city not found. Skipping...
# Processing Record 53 of 630 | kaitangata
# Processing Record 54 of 630 | tsihombe
# tsihombe city not found. Skipping...
# Processing Record 55 of 630 | torbat-e jam
# Processing Record 56 of 630 | kodiak
# Processing Record 57 of 630 | buraydah
# Processing Record 58 of 630 | bluff
# Processing Record 59 of 630 | semnan
# Processing Record 60 of 630 | yellowknife
# Processing Record 61 of 630 | udachnyy
# Processing Record 62 of 630 | castro
# Processing Record 63 of 630 | santa maria
# Processing Record 64 of 630 | yumen
# Processing Record 65 of 630 | puerto ayora
# Processing Record 66 of 630 | liverpool
# Processing Record 67 of 630 | buzmeyin
# Processing Record 68 of 630 | pevek
# Processing Record 69 of 630 | prince rupert
# Processing Record 70 of 630 | nizhneyansk
# nizhneyansk city not found. Skipping...
# Processing Record 71 of 630 | tiarei
# Processing Record 72 of 630 | corner brook
# Processing Record 73 of 630 | viedma
# Processing Record 74 of 630 | kruisfontein
# Processing Record 75 of 630 | butte
# Processing Record 76 of 630 | sentyabrskiy
# sentyabrskiy city not found. Skipping...
# Processing Record 77 of 630 | jiddah
# jiddah city not found. Skipping...
# Processing Record 78 of 630 | ortakoy
# Processing Record 79 of 630 | avera
# Processing Record 80 of 630 | cherskiy
# Processing Record 81 of 630 | pundaguitan
# Processing Record 82 of 630 | high level
# Processing Record 83 of 630 | new norfolk
# Processing Record 84 of 630 | kjopsvik
# Processing Record 85 of 630 | port elizabeth
# Processing Record 86 of 630 | kapaa
# Processing Record 87 of 630 | cabo san lucas
# Processing Record 88 of 630 | flinders
# Processing Record 89 of 630 | puli
# Processing Record 90 of 630 | hokitika
# Processing Record 91 of 630 | sao filipe
# Processing Record 92 of 630 | hermanus
# Processing Record 93 of 630 | saint george
# Processing Record 94 of 630 | vestmannaeyjar
# Processing Record 95 of 630 | boqueirao
# Processing Record 96 of 630 | mahebourg
# Processing Record 97 of 630 | shimoni
# Processing Record 98 of 630 | mbarara
# Processing Record 99 of 630 | port alfred
# Processing Record 100 of 630 | hasaki
# Processing Record 101 of 630 | atuona
# Processing Record 102 of 630 | cabedelo
# Processing Record 103 of 630 | nha trang
# Processing Record 104 of 630 | illoqqortoormiut
# illoqqortoormiut city not found. Skipping...
# Processing Record 105 of 630 | khatanga
# Processing Record 106 of 630 | namatanai
# Processing Record 107 of 630 | chiredzi
# Processing Record 108 of 630 | kingman
# Processing Record 109 of 630 | grand centre
# grand centre city not found. Skipping...
# Processing Record 110 of 630 | jinchang
# Processing Record 111 of 630 | bredasdorp
# Processing Record 112 of 630 | chagda
# chagda city not found. Skipping...
# Processing Record 113 of 630 | qaanaaq
# Processing Record 114 of 630 | barrow
# Processing Record 115 of 630 | arraial do cabo
# Processing Record 116 of 630 | am timan
# Processing Record 117 of 630 | attawapiskat
# attawapiskat city not found. Skipping...
# Processing Record 118 of 630 | vila velha
# Processing Record 119 of 630 | dhali
# Processing Record 120 of 630 | hericourt
# Processing Record 121 of 630 | nemuro
# Processing Record 122 of 630 | port-gentil
# Processing Record 123 of 630 | ancud
# Processing Record 124 of 630 | norman wells
# Processing Record 125 of 630 | coxim
# Processing Record 126 of 630 | manavgat
# Processing Record 127 of 630 | cidreira
# Processing Record 128 of 630 | tulsipur
# Processing Record 129 of 630 | manokwari
# Processing Record 130 of 630 | fort nelson
# Processing Record 131 of 630 | cape town
# Processing Record 132 of 630 | leningradskiy
# Processing Record 133 of 630 | noumea
# Processing Record 134 of 630 | avarua
# Processing Record 135 of 630 | airai
# Processing Record 136 of 630 | isoka
# Processing Record 137 of 630 | zhigansk
# Processing Record 138 of 630 | richards bay
# Processing Record 139 of 630 | obsharovka
# Processing Record 140 of 630 | saint-philippe
# Processing Record 141 of 630 | samarai
# Processing Record 142 of 630 | rio grande
# Processing Record 143 of 630 | hue
# Processing Record 144 of 630 | millau
# Processing Record 145 of 630 | hamilton
# Processing Record 146 of 630 | oussouye
# Processing Record 147 of 630 | kutum
# Processing Record 148 of 630 | north charleston
# Processing Record 149 of 630 | lebu
# Processing Record 150 of 630 | sambava
# Processing Record 151 of 630 | jiazi
# Processing Record 152 of 630 | palmer
# Processing Record 153 of 630 | baykit
# Processing Record 154 of 630 | honiara
# Processing Record 155 of 630 | okha
# Processing Record 156 of 630 | zalesovo
# Processing Record 157 of 630 | kiama
# Processing Record 158 of 630 | husavik
# Processing Record 159 of 630 | marsh harbour
# Processing Record 160 of 630 | tukrah
# Processing Record 161 of 630 | big rapids
# Processing Record 162 of 630 | atar
# Processing Record 163 of 630 | gzhatsk
# gzhatsk city not found. Skipping...
# Processing Record 164 of 630 | gunnedah
# Processing Record 165 of 630 | rawson
# Processing Record 166 of 630 | russell
# Processing Record 167 of 630 | kiomboi
# Processing Record 168 of 630 | ust-kamchatsk
# ust-kamchatsk city not found. Skipping...
# Processing Record 169 of 630 | yulara
# Processing Record 170 of 630 | kachikau
# kachikau city not found. Skipping...
# Processing Record 171 of 630 | saskylakh
# Processing Record 172 of 630 | krugersdorp
# Processing Record 173 of 630 | southbridge
# Processing Record 174 of 630 | severo-kurilsk
# Processing Record 175 of 630 | vardo
# Processing Record 176 of 630 | lagoa
# Processing Record 177 of 630 | kidal
# Processing Record 178 of 630 | balkhash
# Processing Record 179 of 630 | calamar
# Processing Record 180 of 630 | ulaangom
# Processing Record 181 of 630 | dunedin
# Processing Record 182 of 630 | verkhnevilyuysk
# Processing Record 183 of 630 | manadhoo
# Processing Record 184 of 630 | tura
# Processing Record 185 of 630 | lavrentiya
# Processing Record 186 of 630 | ponta do sol
# Processing Record 187 of 630 | sitka
# Processing Record 188 of 630 | mar del plata
# Processing Record 189 of 630 | bambous virieux
# Processing Record 190 of 630 | mareeba
# Processing Record 191 of 630 | tiebissou
# Processing Record 192 of 630 | talnakh
# Processing Record 193 of 630 | tabiauea
# tabiauea city not found. Skipping...
# Processing Record 194 of 630 | merauke
# Processing Record 195 of 630 | hat yai
# Processing Record 196 of 630 | turinsk
# Processing Record 197 of 630 | kavaratti
# Processing Record 198 of 630 | port augusta
# Processing Record 199 of 630 | ilulissat
# Processing Record 200 of 630 | tongliao
# Processing Record 201 of 630 | xining
# Processing Record 202 of 630 | chapais
# Processing Record 203 of 630 | karratha
# Processing Record 204 of 630 | mayya
# Processing Record 205 of 630 | pochutla
# Processing Record 206 of 630 | zavetnoye
# Processing Record 207 of 630 | keti bandar
# Processing Record 208 of 630 | grand river south east
# grand river south east city not found. Skipping...
# Processing Record 209 of 630 | kavieng
# Processing Record 210 of 630 | acapulco
# Processing Record 211 of 630 | sao miguel do araguaia
# Processing Record 212 of 630 | boa vista
# Processing Record 213 of 630 | nador
# Processing Record 214 of 630 | mnogovershinnyy
# Processing Record 215 of 630 | luderitz
# Processing Record 216 of 630 | joshimath
# Processing Record 217 of 630 | saldanha
# Processing Record 218 of 630 | anaco
# Processing Record 219 of 630 | deputatskiy
# Processing Record 220 of 630 | changde
# Processing Record 221 of 630 | kholtoson
# Processing Record 222 of 630 | jurm
# Processing Record 223 of 630 | yakeshi
# Processing Record 224 of 630 | magadan
# Processing Record 225 of 630 | chico
# Processing Record 226 of 630 | barentsburg
# barentsburg city not found. Skipping...
# Processing Record 227 of 630 | hualmay
# Processing Record 228 of 630 | tuatapere
# Processing Record 229 of 630 | coihaique
# Processing Record 230 of 630 | karaul
# karaul city not found. Skipping...
# Processing Record 231 of 630 | pembroke
# Processing Record 232 of 630 | murchison
# Processing Record 233 of 630 | mackenzie
# Processing Record 234 of 630 | yar-sale
# Processing Record 235 of 630 | guerrero negro
# Processing Record 236 of 630 | nanortalik
# Processing Record 237 of 630 | lasa
# Processing Record 238 of 630 | san cristobal
# Processing Record 239 of 630 | egvekinot
# Processing Record 240 of 630 | tadine
# Processing Record 241 of 630 | san felipe
# Processing Record 242 of 630 | uyar
# Processing Record 243 of 630 | comodoro rivadavia
# Processing Record 244 of 630 | dano
# Processing Record 245 of 630 | mao
# Processing Record 246 of 630 | ajdabiya
# Processing Record 247 of 630 | komsomolskiy
# Processing Record 248 of 630 | los llanos de aridane
# Processing Record 249 of 630 | kyabram
# Processing Record 250 of 630 | lakes entrance
# Processing Record 251 of 630 | harrismith
# Processing Record 252 of 630 | olafsvik
# Processing Record 253 of 630 | labutta
# labutta city not found. Skipping...
# Processing Record 254 of 630 | praia da vitoria
# Processing Record 255 of 630 | tumannyy
# tumannyy city not found. Skipping...
# Processing Record 256 of 630 | exeter
# Processing Record 257 of 630 | pitimbu
# Processing Record 258 of 630 | igrim
# Processing Record 259 of 630 | lorengau
# Processing Record 260 of 630 | barabash
# Processing Record 261 of 630 | hervey bay
# Processing Record 262 of 630 | menongue
# Processing Record 263 of 630 | coreau
# Processing Record 264 of 630 | fort saint john
# fort saint john city not found. Skipping...
# Processing Record 265 of 630 | alice springs
# Processing Record 266 of 630 | bengkulu
# Processing Record 267 of 630 | melipilla
# Processing Record 268 of 630 | isiolo
# Processing Record 269 of 630 | baghdad
# Processing Record 270 of 630 | hohhot
# Processing Record 271 of 630 | chimoio
# Processing Record 272 of 630 | mys shmidta
# mys shmidta city not found. Skipping...
# Processing Record 273 of 630 | saint-georges
# Processing Record 274 of 630 | jijiga
# Processing Record 275 of 630 | broken hill
# Processing Record 276 of 630 | yaan
# Processing Record 277 of 630 | atikokan
# Processing Record 278 of 630 | nabire
# Processing Record 279 of 630 | dauphin
# Processing Record 280 of 630 | west fargo
# Processing Record 281 of 630 | ribeira grande
# Processing Record 282 of 630 | souillac
# Processing Record 283 of 630 | chara
# Processing Record 284 of 630 | vaitupu
# vaitupu city not found. Skipping...
# Processing Record 285 of 630 | sola
# Processing Record 286 of 630 | lolua
# lolua city not found. Skipping...
# Processing Record 287 of 630 | erzin
# Processing Record 288 of 630 | cap malheureux
# Processing Record 289 of 630 | tokur
# Processing Record 290 of 630 | hithadhoo
# Processing Record 291 of 630 | acarau
# Processing Record 292 of 630 | krasnoarmeysk
# Processing Record 293 of 630 | porto novo
# Processing Record 294 of 630 | trairi
# Processing Record 295 of 630 | payo
# Processing Record 296 of 630 | bhigvan
# Processing Record 297 of 630 | katiola
# Processing Record 298 of 630 | dongsheng
# Processing Record 299 of 630 | koslan
# Processing Record 300 of 630 | mujiayingzi
# Processing Record 301 of 630 | hollins
# Processing Record 302 of 630 | chengde
# Processing Record 303 of 630 | raudeberg
# Processing Record 304 of 630 | cockburn town
# Processing Record 305 of 630 | puerto del rosario
# Processing Record 306 of 630 | havelock
# Processing Record 307 of 630 | hamptons at boca raton
# Processing Record 308 of 630 | boden
# Processing Record 309 of 630 | san quintin
# Processing Record 310 of 630 | ituni
# ituni city not found. Skipping...
# Processing Record 311 of 630 | ta khmau
# Processing Record 312 of 630 | kuching
# Processing Record 313 of 630 | marshfield
# Processing Record 314 of 630 | gorno-chuyskiy
# gorno-chuyskiy city not found. Skipping...
# Processing Record 315 of 630 | baripada
# Processing Record 316 of 630 | young
# Processing Record 317 of 630 | ilmajoki
# Processing Record 318 of 630 | kapit
# Processing Record 319 of 630 | aksu
# Processing Record 320 of 630 | trelew
# Processing Record 321 of 630 | kumluca
# Processing Record 322 of 630 | harrisburg
# Processing Record 323 of 630 | port hardy
# Processing Record 324 of 630 | alta floresta
# Processing Record 325 of 630 | eydhafushi
# Processing Record 326 of 630 | davila
# Processing Record 327 of 630 | horodnytsya
# Processing Record 328 of 630 | amderma
# amderma city not found. Skipping...
# Processing Record 329 of 630 | henties bay
# Processing Record 330 of 630 | clyde river
# Processing Record 331 of 630 | provideniya
# Processing Record 332 of 630 | kuche
# kuche city not found. Skipping...
# Processing Record 333 of 630 | panguna
# Processing Record 334 of 630 | kloulklubed
# Processing Record 335 of 630 | asau
# Processing Record 336 of 630 | taoudenni
# Processing Record 337 of 630 | yarim
# Processing Record 338 of 630 | constitucion
# Processing Record 339 of 630 | evensk
# Processing Record 340 of 630 | marystown
# Processing Record 341 of 630 | santa maria del oro
# Processing Record 342 of 630 | saleaula
# saleaula city not found. Skipping...
# Processing Record 343 of 630 | maihar
# Processing Record 344 of 630 | sogdiondon
# sogdiondon city not found. Skipping...
# Processing Record 345 of 630 | yunjinghong
# yunjinghong city not found. Skipping...
# Processing Record 346 of 630 | bairiki
# Processing Record 347 of 630 | pskov
# Processing Record 348 of 630 | barentu
# Processing Record 349 of 630 | gondar
# Processing Record 350 of 630 | lompoc
# Processing Record 351 of 630 | preston
# Processing Record 352 of 630 | kudahuvadhoo
# Processing Record 353 of 630 | san jose del palmar
# Processing Record 354 of 630 | norwich
# Processing Record 355 of 630 | oistins
# Processing Record 356 of 630 | warner robins
# Processing Record 357 of 630 | vila
# Processing Record 358 of 630 | port blair
# Processing Record 359 of 630 | hobyo
# Processing Record 360 of 630 | half moon bay
# Processing Record 361 of 630 | banjar
# Processing Record 362 of 630 | hinton
# Processing Record 363 of 630 | bedford
# Processing Record 364 of 630 | canico
# Processing Record 365 of 630 | jalu
# Processing Record 366 of 630 | bonthe
# Processing Record 367 of 630 | nisia floresta
# Processing Record 368 of 630 | satitoa
# satitoa city not found. Skipping...
# Processing Record 369 of 630 | chuy
# Processing Record 370 of 630 | sakakah
# Processing Record 371 of 630 | benguela
# Processing Record 372 of 630 | birao
# Processing Record 373 of 630 | chino valley
# Processing Record 374 of 630 | louisbourg
# louisbourg city not found. Skipping...
# Processing Record 375 of 630 | alofi
# Processing Record 376 of 630 | fortuna
# Processing Record 377 of 630 | conceicao do araguaia
# Processing Record 378 of 630 | berbera
# Processing Record 379 of 630 | hami
# Processing Record 380 of 630 | coos bay
# Processing Record 381 of 630 | ercis
# Processing Record 382 of 630 | katsuura
# Processing Record 383 of 630 | bethel
# Processing Record 384 of 630 | kahului
# Processing Record 385 of 630 | mormugao
# Processing Record 386 of 630 | hovd
# Processing Record 387 of 630 | wajima
# Processing Record 388 of 630 | seoul
# Processing Record 389 of 630 | cumanayagua
# Processing Record 390 of 630 | tessalit
# Processing Record 391 of 630 | umm kaddadah
# Processing Record 392 of 630 | shakiso
# Processing Record 393 of 630 | caceres
# Processing Record 394 of 630 | zelenoborsk
# Processing Record 395 of 630 | inhambane
# Processing Record 396 of 630 | quatre cocos
# Processing Record 397 of 630 | ushtobe
# Processing Record 398 of 630 | plettenberg bay
# Processing Record 399 of 630 | victoria
# Processing Record 400 of 630 | marang
# Processing Record 401 of 630 | vicar
# Processing Record 402 of 630 | tchibanga
# Processing Record 403 of 630 | vao
# Processing Record 404 of 630 | san angelo
# Processing Record 405 of 630 | wadi maliz
# Processing Record 406 of 630 | suluq
# Processing Record 407 of 630 | ruidoso
# Processing Record 408 of 630 | inta
# Processing Record 409 of 630 | tomatlan
# Processing Record 410 of 630 | banfora
# Processing Record 411 of 630 | santa cruz
# Processing Record 412 of 630 | bathsheba
# Processing Record 413 of 630 | vila franca do campo
# Processing Record 414 of 630 | sabang
# Processing Record 415 of 630 | ouadda
# Processing Record 416 of 630 | urumqi
# Processing Record 417 of 630 | abu samrah
# Processing Record 418 of 630 | isangel
# Processing Record 419 of 630 | gurkovo
# Processing Record 420 of 630 | invermere
# Processing Record 421 of 630 | ahipara
# Processing Record 422 of 630 | sembe
# Processing Record 423 of 630 | victor harbor
# Processing Record 424 of 630 | norsup
# Processing Record 425 of 630 | goderich
# Processing Record 426 of 630 | iquitos
# Processing Record 427 of 630 | marsa matruh
# Processing Record 428 of 630 | haibowan
# haibowan city not found. Skipping...
# Processing Record 429 of 630 | touros
# Processing Record 430 of 630 | marienburg
# Processing Record 431 of 630 | makakilo city
# Processing Record 432 of 630 | safaga
# Processing Record 433 of 630 | port lincoln
# Processing Record 434 of 630 | camacupa
# Processing Record 435 of 630 | narrabri
# Processing Record 436 of 630 | okhotsk
# Processing Record 437 of 630 | maturin
# Processing Record 438 of 630 | gigmoto
# Processing Record 439 of 630 | petropavlovsk-kamchatskiy
# Processing Record 440 of 630 | ambon
# Processing Record 441 of 630 | mehamn
# Processing Record 442 of 630 | laguna
# Processing Record 443 of 630 | popondetta
# Processing Record 444 of 630 | la rioja
# Processing Record 445 of 630 | mocorito
# Processing Record 446 of 630 | osoyoos
# Processing Record 447 of 630 | shingu
# Processing Record 448 of 630 | qandala
# Processing Record 449 of 630 | murovani kurylivtsi
# Processing Record 450 of 630 | saint-francois
# Processing Record 451 of 630 | lamu
# Processing Record 452 of 630 | sangar
# Processing Record 453 of 630 | mattawa
# Processing Record 454 of 630 | filingue
# Processing Record 455 of 630 | college
# Processing Record 456 of 630 | port hedland
# Processing Record 457 of 630 | salalah
# Processing Record 458 of 630 | inuvik
# Processing Record 459 of 630 | coquimbo
# Processing Record 460 of 630 | harper
# Processing Record 461 of 630 | itoman
# Processing Record 462 of 630 | zambezi
# Processing Record 463 of 630 | novoagansk
# Processing Record 464 of 630 | srednekolymsk
# Processing Record 465 of 630 | formoso do araguaia
# formoso do araguaia city not found. Skipping...
# Processing Record 466 of 630 | saint-augustin
# Processing Record 467 of 630 | taltal
# Processing Record 468 of 630 | sistranda
# Processing Record 469 of 630 | pontianak
# Processing Record 470 of 630 | sabha
# Processing Record 471 of 630 | mackay
# Processing Record 472 of 630 | inirida
# Processing Record 473 of 630 | dhidhdhoo
# Processing Record 474 of 630 | amahai
# Processing Record 475 of 630 | albox
# Processing Record 476 of 630 | omboue
# Processing Record 477 of 630 | edd
# Processing Record 478 of 630 | bilibino
# Processing Record 479 of 630 | dzilam gonzalez
# Processing Record 480 of 630 | kerouane
# Processing Record 481 of 630 | pangody
# Processing Record 482 of 630 | maua
# Processing Record 483 of 630 | umm lajj
# Processing Record 484 of 630 | kindu
# Processing Record 485 of 630 | sobolevo
# Processing Record 486 of 630 | uzumlu
# uzumlu city not found. Skipping...
# Processing Record 487 of 630 | berlevag
# Processing Record 488 of 630 | pipar
# Processing Record 489 of 630 | sendafa
# Processing Record 490 of 630 | kirkenaer
# Processing Record 491 of 630 | ballina
# Processing Record 492 of 630 | malatya
# Processing Record 493 of 630 | naze
# Processing Record 494 of 630 | lexington park
# Processing Record 495 of 630 | beloha
# Processing Record 496 of 630 | dolinsk
# Processing Record 497 of 630 | gat
# Processing Record 498 of 630 | clevelandia
# Processing Record 499 of 630 | along
# Processing Record 500 of 630 | caravelas
# Processing Record 501 of 630 | haines junction
# Processing Record 502 of 630 | namibe
# Processing Record 503 of 630 | bajo baudo
# bajo baudo city not found. Skipping...
# Processing Record 504 of 630 | samusu
# samusu city not found. Skipping...
# Processing Record 505 of 630 | kushiro
# Processing Record 506 of 630 | clarksburg
# Processing Record 507 of 630 | bhola
# Processing Record 508 of 630 | forbes
# Processing Record 509 of 630 | bagdarin
# Processing Record 510 of 630 | setermoen
# Processing Record 511 of 630 | poronaysk
# Processing Record 512 of 630 | murray bridge
# Processing Record 513 of 630 | bakel
# Processing Record 514 of 630 | chaguanas
# Processing Record 515 of 630 | basco
# Processing Record 516 of 630 | snezhnogorsk
# Processing Record 517 of 630 | kazalinsk
# kazalinsk city not found. Skipping...
# Processing Record 518 of 630 | eureka
# Processing Record 519 of 630 | nouakchott
# Processing Record 520 of 630 | leh
# Processing Record 521 of 630 | ramhormoz
# Processing Record 522 of 630 | wulanhaote
# wulanhaote city not found. Skipping...
# Processing Record 523 of 630 | olinala
# Processing Record 524 of 630 | carros
# Processing Record 525 of 630 | arrecife
# Processing Record 526 of 630 | pingliang
# Processing Record 527 of 630 | gangotri
# gangotri city not found. Skipping...
# Processing Record 528 of 630 | rosarito
# Processing Record 529 of 630 | oda
# Processing Record 530 of 630 | ouegoa
# Processing Record 531 of 630 | san rafael
# Processing Record 532 of 630 | tabukiniberu
# tabukiniberu city not found. Skipping...
# Processing Record 533 of 630 | sinnamary
# Processing Record 534 of 630 | belaya gora
# Processing Record 535 of 630 | iqaluit
# Processing Record 536 of 630 | ornskoldsvik
# Processing Record 537 of 630 | cayenne
# Processing Record 538 of 630 | bentiu
# Processing Record 539 of 630 | sai buri
# Processing Record 540 of 630 | chicama
# Processing Record 541 of 630 | bogashevo
# Processing Record 542 of 630 | palasa
# Processing Record 543 of 630 | baixa grande
# Processing Record 544 of 630 | pisco
# Processing Record 545 of 630 | spring valley
# Processing Record 546 of 630 | lewistown
# Processing Record 547 of 630 | oktyabrskiy
# Processing Record 548 of 630 | marrakesh
# Processing Record 549 of 630 | mancio lima
# Processing Record 550 of 630 | acuna
# acuna city not found. Skipping...
# Processing Record 551 of 630 | amapa
# Processing Record 552 of 630 | shimoda
# Processing Record 553 of 630 | huanren
# Processing Record 554 of 630 | preobrazheniye
# Processing Record 555 of 630 | uaua
# Processing Record 556 of 630 | neuquen
# Processing Record 557 of 630 | san fernando
# Processing Record 558 of 630 | purranque
# Processing Record 559 of 630 | talcahuano
# Processing Record 560 of 630 | ostrovnoy
# Processing Record 561 of 630 | mount vernon
# Processing Record 562 of 630 | qasigiannguit
# Processing Record 563 of 630 | amalner
# Processing Record 564 of 630 | la ronge
# Processing Record 565 of 630 | mul
# Processing Record 566 of 630 | andenes
# Processing Record 567 of 630 | cajaruro
# Processing Record 568 of 630 | palabuhanratu
# palabuhanratu city not found. Skipping...
# Processing Record 569 of 630 | honningsvag
# Processing Record 570 of 630 | paamiut
# Processing Record 571 of 630 | teguise
# Processing Record 572 of 630 | atambua
# Processing Record 573 of 630 | tiksi
# Processing Record 574 of 630 | umm bab
# Processing Record 575 of 630 | dongying
# Processing Record 576 of 630 | kaspiysk
# Processing Record 577 of 630 | mahajanga
# Processing Record 578 of 630 | soe
# Processing Record 579 of 630 | santiago
# Processing Record 580 of 630 | steamboat springs
# Processing Record 581 of 630 | cam ranh
# Processing Record 582 of 630 | dakar
# Processing Record 583 of 630 | iralaya
# Processing Record 584 of 630 | noyabrsk
# Processing Record 585 of 630 | faanui
# Processing Record 586 of 630 | tautira
# Processing Record 587 of 630 | nouadhibou
# Processing Record 588 of 630 | formosa
# Processing Record 589 of 630 | nampula
# Processing Record 590 of 630 | rocha
# Processing Record 591 of 630 | angoram
# Processing Record 592 of 630 | naryan-mar
# Processing Record 593 of 630 | kupang
# Processing Record 594 of 630 | teguldet
# Processing Record 595 of 630 | belousovka
# Processing Record 596 of 630 | nurota
# Processing Record 597 of 630 | kenmare
# Processing Record 598 of 630 | adrar
# Processing Record 599 of 630 | san joaquin
# Processing Record 600 of 630 | kirakira
# Processing Record 601 of 630 | orchard homes
# Processing Record 602 of 630 | zheleznodorozhnyy
# Processing Record 603 of 630 | urucara
# Processing Record 604 of 630 | aykhal
# Processing Record 605 of 630 | naples
# Processing Record 606 of 630 | ust-omchug
# Processing Record 607 of 630 | ridgecrest
# Processing Record 608 of 630 | crystal beach
# Processing Record 609 of 630 | banon
# Processing Record 610 of 630 | verkhnetulomskiy
# Processing Record 611 of 630 | jumla
# Processing Record 612 of 630 | antofagasta
# Processing Record 613 of 630 | batagay-alyta
# Processing Record 614 of 630 | tornio
# Processing Record 615 of 630 | krasnoselkup
# Processing Record 616 of 630 | port-cartier
# Processing Record 617 of 630 | hambantota
# Processing Record 618 of 630 | ewa beach
# Processing Record 619 of 630 | huron
# Processing Record 620 of 630 | areosa
# Processing Record 621 of 630 | gamba
# Processing Record 622 of 630 | bull savanna
# Processing Record 623 of 630 | herat
# Processing Record 624 of 630 | novikovo
# Processing Record 625 of 630 | juba
# Processing Record 626 of 630 | gornopravdinsk
# Processing Record 627 of 630 | palana
# Processing Record 628 of 630 | lazaro cardenas
# Processing Record 629 of 630 | eufaula
# Processing Record 630 of 630 | lagodekhi

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Create and Display DataFrame a data frame from api call list:
weather_dictionary = {
    "City": city_name,
    "Lat":lat,
    "Lng":lng,
    "Max Temp": max_temp,
    "Humidity": humidity,
    "Cloudiness":cloudiness,
    "Wind Speed":wind_speed,
    "Country":country,
    "Date":date   
    
}

weather_data = pd.DataFrame(weather_dictionary)

#Display the DataFrame 
weather_data.count()
# Out:
# City          584
# Lat           584
# Lng           584
# Max Temp      584
# Humidity      584
# Cloudiness    584
# Wind Speed    584
# Country       584
# Date          584
# dtype: int64

# %%
# Save data frame to CSV
weather_data.to_csv("output_data/cities.csv")

# Display data frame head 
weather_data.head()
# Out:
#          City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0      Anadyr  64.75  177.48     42.80        87          20       11.18
# 1  Partizansk  43.13  133.13     57.70        89         100        2.37
# 2    Klaksvík  62.23   -6.59     48.20       100           9        9.17
# 3     Ushuaia -54.80  -68.30     31.91        94          98        8.55
# 4  Nikolskoye  59.70   30.79     73.99        49          78        6.71
#
#   Country        Date
# 0      RU  1592207284
# 1      RU  1592207313
# 2      FO  1592207313
# 3      AR  1592207073
# 4      RU  1592207314

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
weather_data.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  584.000000  584.000000  584.000000  584.000000  584.000000  584.000000
# mean    19.744195   20.516233   69.148390   66.491438   49.054795    8.739264
# std     32.940104   90.873345   15.462278   23.284723   39.218267    5.853932
# min    -54.800000 -179.170000   30.200000    7.000000    0.000000    0.510000
# 25%     -6.400000  -59.815000   57.697500   50.750000    6.000000    4.470000
# 50%     22.885000   25.875000   70.430000   73.000000   40.500000    7.390000
# 75%     45.970000  101.657500   80.100000   84.000000   90.000000   11.545000
# max     78.220000  178.420000  111.200000  100.000000  100.000000   36.910000
#
#                Date
# count  5.840000e+02
# mean   1.592207e+09
# std    5.314112e+01
# min    1.592207e+09
# 25%    1.592207e+09
# 50%    1.592207e+09
# 75%    1.592207e+09
# max    1.592207e+09

# %%
#  Get the indices of cities that have humidity over 100%.
weather_data.index
# Out:
# RangeIndex(start=0, stop=584, step=1)

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %%
# Extract relevant fields from the data frame


# Export the City_Data into a csv

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Build a scatter plot for each data type
#plt.figure(figsize=(9,5))
plt.scatter(weather_data["Lat"], weather_data["Max Temp"], marker="o", s = [20], edgecolors='black')

# Incorporate the other graph properties
plt.title('City Latitude vs. Max Temperature ' + '(' + datetime.today().strftime('%m/%d/%y') + ')')
plt.ylabel("Max. Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Max_Temp_vs_Latitude.png")

# Show plot
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Build a scatter plot for each data type
plt.figure(figsize=(9,5))
plt.scatter(weather_data["Lat"], weather_data["Humidity"], marker="o", s = [20], edgecolors='black')

# Incorporate the other graph properties
plt.title('City Latitude vs. Humidity ' + '(' + datetime.today().strftime('%m/%d/%y') + ')')
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Humidity_vs_Latitude.png")

# Show plot
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Build a scatter plot for each data type
plt.figure(figsize=(9,5))
plt.scatter(weather_data["Lat"], weather_data["Cloudiness"], marker="o", s = [20], edgecolors='black')

# Incorporate the other graph properties
plt.title('City Latitude vs. Cloudiness' + '(' + datetime.today().strftime('%m/%d/%y') + ')')
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Cloudiness_vs_Latitude.png")

# Show plot
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Wind Speed"], marker="o", s=20)

# Incorporate the other graph properties
plt.title('City Latitude vs. Wind Speed' + '(' + datetime.today().strftime('%m/%d/%y') + ')')
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Wind_Speed_vs_Latitude.png")

# Show plot
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
# Create Northern and Southern Hemisphere DataFrames# Create new data frame for northern hemisphere (lat >= 0 degree):
weather_data_north = weather_data[weather_data['Lat'] >= 0]

#weather_data_north.count()

# Create new data frame for southern hemisphere (lat < 0 degree):
weather_data_south = weather_data[weather_data['Lat'] < 0]

#weather_data_south.count()

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Build scatter plot for each data type:
plt.figure(figsize = (9,6))
x_values = weather_data_north['Lat']
y_values = weather_data_north['Max Temp']

# Perform a linear regression for temperature vs. latitude:
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Get regression values:
regress_values = x_values * slope + intercept

# Create line equation string:
line_eq = 'y = ' + str(round(slope,2)) + 'x + ' + str(round(intercept,2))

# Create plot:
plt.scatter(x_values,y_values, marker = 'o', s=[50])
plt.plot(x_values,regress_values,"r-")

# Incorporate the other graph properties:
plt.title('Northern Hemisphere - Max Temp vs. Latitude', fontsize=20)
plt.ylabel('Max Temp')
plt.xlabel('Latitude')
plt.annotate(line_eq,(6, 10),fontsize=15,color="red")



# limits of the y axis:
plt.ylim(min(weather_data['Max Temp'])-10, max(weather_data['Max Temp'])+10)

#limits of the x axis:
plt.xlim(-3, max(weather_data['Lat'])+3)

# Print r-squared value:
print(f'The r-squared is: {rvalue**2}')

# Save the figure:
plt.savefig('output_data/City Latitude vs. MaxTemp_North.png')

# Show plot:
plt.show()
# Out:
# The r-squared is: 0.417862031579353

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Build scatter plot for each data type:
plt.figure(figsize=(9,6))
x_values = weather_data_south['Lat']
y_values = weather_data_south['Max Temp']

# Perform a linear regression for temperature vs. latitude:
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Get regression values:
regress_values = x_values * slope + intercept

# Create line equation string:
line_eq2 = 'y = ' + str(round(slope,2)) + 'x + ' + str(round(intercept,2))

# Create plot:
plt.scatter(x_values,y_values, marker='o', s=[50])
plt.plot(x_values,regress_values, 'red')

# Incorporate the other graph properties:
plt.title('Southern Hemisphere - Max Temp vs. Latitude')
plt.ylabel('Max Temperature')
plt.xlabel('Latitude', fontsize=16, color='black')
plt.annotate(line_eq2,(-25,43), fontsize = 15, color = 'red')
#plt.grid(False)

#limits of the y axis:
plt.ylim(30, 100)

#limits of the x axis:
plt.xlim(min(weather_data['Lat'])-3, +1)

# Print r-squared value:
print(f'The r-squared is: {round(rvalue**2,2)}')

# Save the figure:
plt.savefig('output_data/City Latitude vs. MaxTemp_South.png')

# Show plot:
plt.show()
# Out:
# The r-squared is: 0.64

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Build scatter plot for each data type:
plt.figure(figsize=(9,6))
x_values = weather_data_north['Lat']
y_values = weather_data_north['Humidity']

# Perform a linear regression for humidity vs. latitude:
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Get regression values:
regress_values = x_values * slope + intercept

# Create line equation string:
line_eq = 'y = ' + str(round(slope,2)) + 'x + ' + str(round(intercept,2))

# Create plot:
plt.scatter(x_values,y_values, marker='o', s=[70])
plt.plot(x_values,regress_values, 'red')

# Incorporate the other graph properties:
plt.title('Northern Hemisphere - Humidity vs. Latitude')
plt.ylabel('Humidity')
plt.xlabel('Latitude')
plt.annotate(line_eq2,(-25,43), fontsize = 15, color = 'red')
#plt.grid(False)

#limits of the y axis:
plt.ylim(-6, 110)

#limits of the x axis:
plt.xlim(-4, 82)

# Print r-squared value:
print(f'The r-squared is: {round(rvalue**2,7)}')

# Save the figure:
plt.savefig('output_data/City Latitude vs. Humidity_North.png')

# Show plot:
plt.show()
# Out:
# The r-squared is: 0.0046723

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Build scatter plot for each data type:
plt.figure(figsize=(9,6))
x_values = weather_data_south['Lat']
y_values = weather_data_south['Humidity']

# Perform a linear regression for humidity vs. latitude:
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Get regression values:
regress_values = x_values * slope + intercept

# Create line equation string:
line_eq = 'y = ' + str(round(slope,2)) + 'x + ' + str(round(intercept,2))

# Create plot:
plt.scatter(x_values,y_values, marker='o', color='blue', s=[70], edgecolors='black')
plt.plot(x_values,regress_values, 'red')

# Incorporate the other graph properties:
plt.title('Southern Hemisphere - Humidity vs. Latitude', fontsize=20)
plt.ylabel('Humidity', fontsize=16, color='black')
plt.xlabel('Latitude', fontsize=16, color='black')
plt.annotate(line_eq,(-55,22), fontsize= 18, color='red')
#plt.grid(False)

# Set the limits of the y axis:
plt.ylim(10, 110)

# Set the limits of the x axis:
plt.xlim(-57, 1)

# Print r-squared value:
print(f'The r-squared is: {round(rvalue**2,2)}')

# Save the figure:
plt.savefig('output_data/City Latitude vs. Humidity_South.png')

# Show plot:
plt.show()
# Out:
# The r-squared is: 0.01

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Build scatter plot for each data type:
plt.figure(figsize=(9,6))
x_values = weather_data_north['Lat']
y_values = weather_data_north['Cloudiness']

# Perform a linear regression for cloudiness vs. latitude:
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Get regression values:
regress_values = x_values * slope + intercept

# Create line equation string:
line_eq = 'y = ' + str(round(slope,2)) + 'x + ' + str(round(intercept,2))

# Create plot:
plt.scatter(x_values,y_values, marker='o', color='blue', s=[50], edgecolors='black')
plt.plot(x_values,regress_values,'red')

# Incorporate the other graph properties:
plt.title('Northern Hemisphere - Cloudiness (%) vs. Latitude', fontsize=20)
plt.ylabel('Cloudiness', fontsize=16, color='black')
plt.xlabel('Latitude', fontsize=16, color='black')
plt.annotate(line_eq,(35,25), fontsize=18, color='red')
#plt.grid(False)

# Set the limits of the y axis:
plt.ylim(-8, 110)

# Set the limits of the x axis:
plt.xlim(-3, 82)

# Print r-squared value:
print(f'The r-squared is: {round(rvalue**2,10)}')

# Save the figure:
plt.savefig('output_data/City Latitude vs. Cloudiness_North.png')

# Show plot:
plt.show()
# Out:
# The r-squared is: 0.001690067

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# build scatter plot for each data type:
plt.figure(figsize=(9,6))
x_values = weather_data_south['Lat']
y_values = weather_data_south['Cloudiness']

# Perform a linear regression for cloudiness vs. latitude:
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Get regression values:
regress_values = x_values * slope + intercept

# Create line equation string:
line_eq = 'y = ' + str(round(slope,2)) + 'x + ' + str(round(intercept,2))

# Create plot:
plt.scatter(x_values,y_values, marker='o', color='blue', s=[70], edgecolors='black')
plt.plot(x_values,regress_values,'red')

# Incorporate the other graph properties:
plt.title('Southern Hemisphere - Cloudiness (%) vs. Latitude', fontsize=20)
plt.ylabel('Cloudiness', fontsize=16, color='black')
plt.xlabel('Latitude', fontsize=16, color='black')
plt.annotate(line_eq,(-56,8), fontsize=18, color='red')
#plt.grid(False)

# limits of the y axis:
plt.ylim(-7, 108)

# limits of the x axis:
plt.xlim(-58, 1)

# Print r-squared value:
print(f'The r-squared is: {round(rvalue**2,12)}')

# Save the figure:
plt.savefig('output_data/City Latitude vs. Cloudiness_South.png')

# Show plot:
plt.show()
# Out:
# The r-squared is: 0.000579120639

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Build scatter plot for each data type:
plt.figure(figsize=(9,6))
x_values = weather_data_north['Lat']
y_values = weather_data_north['Wind Speed']

# Perform a linear regression for wind speed vs. latitude:
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Get regression values:
regress_values = x_values * slope + intercept

# Create line equation string:
line_eq = 'y = ' + str(round(slope,2)) + 'x + ' + str(round(intercept,2))

# Create plot:
plt.scatter(x_values,y_values, marker='o', color='blue', s=[70], edgecolors='black')
plt.plot(x_values,regress_values,'red')

# Incorporate the other graph properties:
plt.title('Northern Hemisphere - Wind Speed vs. Latitude', fontsize=20)
plt.ylabel('Wind Speed', fontsize = 16, color ='black')
plt.xlabel('Latitude', fontsize=16, color='black')
plt.annotate(line_eq,(2,42), fontsize=18, color='red')
#plt.grid(False)

# limits of the y axis:
plt.ylim(-3, 48)

# limits of the x axis:
plt.xlim(-3, 82)

# Print r-squared value:
print(f'The r-squared is: {round(rvalue**2,12)}')

# Save the figure:
plt.savefig('output_data/City Latitude vs. Wind_North.png')

# Show plot:
plt.show()
# Out:
# The r-squared is: 0.006984571135

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Build scatter plot for each data type:
plt.figure(figsize=(9,6))
x_values = weather_data_south['Lat']
y_values = weather_data_south['Wind Speed']

# Perform a linear regression on wind speed vs. latitude:
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Get regression values:
regress_values = x_values * slope + intercept

# Create line equation string:
line_eq = 'y = ' + str(round(slope,2)) + 'x + ' + str(round(intercept,2))

# Create plot:
plt.scatter(x_values,y_values, marker='o', color='blue', s=[70], edgecolors='black')
plt.plot(x_values,regress_values,'red')

# Incorporate the other graph properties:
plt.title('Southern Hemisphere - Wind Speed vs. Latitude', fontsize=20)
plt.ylabel('Wind Speed', fontsize = 16, color='black')
plt.xlabel('Latitude', fontsize = 16, color = 'black')
plt.annotate(line_eq,(-19.5,21), fontsize=18, color='red')
#plt.grid(False)

# limits of the y axis:
plt.ylim(-1, 25)

# limits of the x axis:
plt.xlim(-58, 1)

# Print r-squared value:
print(f'The r-squared is: {round(rvalue**2,12)}')

# Save the figure:
plt.savefig('output_data/City Latitude vs. Wind_South.png')

# Show plot:
plt.show()
# Out:
# The r-squared is: 0.003017277161
